# %% [markdown]
# <a href="https://colab.research.google.com/github/aniketbaghel9040-cyber/NLP-Notes/blob/main/NLP(nltk).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
import urllib.request

try:
    print(urllib.request.urlopen("https://www.google.com").status)
except Exception as e:
    print(e)
# Out:
# 200

# %%
from nltk.tokenize import word_tokenize

text = "Hello! My name is Aniket. I am learning now  in NLP and my teacher name is Dr. Megha Gupta maam."

tokens = word_tokenize(text)

print(tokens)
# Out:
# ['Hello', '!', 'My', 'name', 'is', 'Aniket', '.', 'I', 'am', 'learning', 'now', 'ans', 'in', 'NLP', '.']

# %%
 var = "Neuro-Linguistic Programming (Psychology)Definition: A framework exploring how our nervous system, language choices, and behavioral patterns shape our daily experiences.Core Focus: Examines internal thought processes and communication habits to achieve personal growth.Common Uses: Applied in coaching, counseling, and communication skills training"

# %%
var
# Out:
# 'Neuro-Linguistic Programming (Psychology)Definition: A framework exploring how our nervous system, language choices, and behavioral patterns shape our daily experiences.Core Focus: Examines internal thought processes and communication habits to achieve personal growth.Common Uses: Applied in coaching, counseling, and communication skills training'

# %% [markdown]
# import word and sent tokenize

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
sent =  sent_tokenize(var)

# %%
sent
# Out:
# ['Neuro-Linguistic Programming (Psychology)Definition: A framework exploring how our nervous system, language choices, and behavioral patterns shape our daily experiences.Core Focus: Examines internal thought processes and communication habits to achieve personal growth.Common Uses: Applied in coaching, counseling, and communication skills training']

# %%
for i in sent :
    print(i)
    print()
# Out:
# Neuro-Linguistic Programming (Psychology)Definition: A framework exploring how our nervous system, language choices, and behavioral patterns shape our daily experiences.Core Focus: Examines internal thought processes and communication habits to achieve personal growth.Common Uses: Applied in coaching, counseling, and communication skills training

# %% [markdown]
# word tokenize

# %%
word = word_tokenize(var)
word
# Out:
# ['Neuro-Linguistic',
#  'Programming',
#  '(',
#  'Psychology',
#  ')',
#  'Definition',
#  ':',
#  'A',
#  'framework',
#  'exploring',
#  'how',
#  'our',
#  'nervous',
#  'system',
#  ',',
#  'language',
#  'choices',
#  ',',
#  'and',
#  'behavioral',
#  'patterns',
#  'shape',
#  'our',
#  'daily',
#  'experiences.Core',
#  'Focus',
#  ':',
#  'Examines',
#  'internal',
#  'thought',
#  'processes',
#  'and',
#  'communication',
#  'habits',
#  'to',
#  'achieve',
#  'personal',
#  'growth.Common',
#  'Uses',
#  ':',
#  'Applied',
#  'in',
#  'coaching',
#  ',',
#  'counseling',
#  ',',
#  'and',
#  'communication',
#  'skills',
#  'training']

# %%
import nltk

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')  # For newer NLTK versions
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

text = "The boy is playing in the park."

stop_words = set(stopwords.words('english'))

words = word_tokenize(text)

filtered_words = []

for word in words:
    if word.lower() not in stop_words:
        filtered_words.append(word)

print("Original Words:")
print(words)

print("\nAfter Removing Stopwords:")
print(filtered_words)
# Out:
# Original Words:
# ['The', 'boy', 'is', 'playing', 'in', 'the', 'park', '.']
#
# After Removing Stopwords:
# ['boy', 'playing', 'park', '.']

# %%
from nltk.corpus import stopwords

stop_words = stopwords.words('english')

print(stop_words)
print("Total Stopwords:", len(stop_words))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...
