# %% [markdown]
# <a href="https://colab.research.google.com/github/aniketbaghel9040-cyber/NLP-Notes/blob/main/thisday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk spacy
# !python -m spacy download en_core_web_
sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 31.9 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
import string
import nltk
import spacy

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from collections import Counter

# %%
text = """
Apple is looking at buying a startup in the United Kingdom for $1 billion.
The company was founded by John in 2019.
He loves running, playing football and reading books.
"""

# %%
tokens = word_tokenize(text)

print(tokens)
# Out:
# ['Apple', 'is', 'looking', 'at', 'buying', 'a', 'startup', 'in', 'the', 'United', 'Kingdom', 'for', '$', '1', 'billion', '.', 'The', 'company', 'was', 'founded', 'by', 'John', 'in', '2019', '.', 'He', 'loves', 'running', ',', 'playing', 'football', 'and', 'reading', 'books', '.']

# %%
tokens = [word.lower() for word in tokens]

print(tokens)
# Out:
# ['apple', 'is', 'looking', 'at', 'buying', 'a', 'startup', 'in', 'the', 'united', 'kingdom', 'for', '$', '1', 'billion', '.', 'the', 'company', 'was', 'founded', 'by', 'john', 'in', '2019', '.', 'he', 'loves', 'running', ',', 'playing', 'football', 'and', 'reading', 'books', '.']

# %%
tokens = [word for word in tokens if word not in string.punctuation]

print(tokens)
# Out:
# ['apple', 'is', 'looking', 'at', 'buying', 'a', 'startup', 'in', 'the', 'united', 'kingdom', 'for', '1', 'billion', 'the', 'company', 'was', 'founded', 'by', 'john', 'in', '2019', 'he', 'loves', 'running', 'playing', 'football', 'and', 'reading', 'books']

# %%
stop_words = set(stopwords.words("english"))

filtered = [word for word in tokens if word not in stop_words]

print(filtered)
# Out:
# ['apple', 'looking', 'buying', 'startup', 'united', 'kingdom', '1', 'billion', 'company', 'founded', 'john', '2019', 'loves', 'running', 'playing', 'football', 'reading', 'books']

# %%
stemmer = PorterStemmer()

stemmed = [stemmer.stem(word) for word in filtered]

print(stemmed)
# Out:
# ['appl', 'look', 'buy', 'startup', 'unit', 'kingdom', '1', 'billion', 'compani', 'found', 'john', '2019', 'love', 'run', 'play', 'footbal', 'read', 'book']

# %%
lemmatizer = WordNetLemmatizer()

lemmatized = [lemmatizer.lemmatize(word) for word in filtered]

print(lemmatized)
# Out:
# ['apple', 'looking', 'buying', 'startup', 'united', 'kingdom', '1', 'billion', 'company', 'founded', 'john', '2019', 'love', 'running', 'playing', 'football', 'reading', 'book']

# %%
frequency = Counter(lemmatized)

print(frequency)

print("\nTop 10 Words")

for word, count in frequency.most_common(10):
    print(word, ":", count)
# Out:
# Counter({'apple': 1, 'looking': 1, 'buying': 1, 'startup': 1, 'united': 1, 'kingdom': 1, '1': 1, 'billion': 1, 'company': 1, 'founded': 1, 'john': 1, '2019': 1, 'love': 1, 'running': 1, 'playing': 1, 'football': 1, 'reading': 1, 'book': 1})
#
# Top 10 Words
# apple : 1
# looking : 1
# buying : 1
# startup : 1
# united : 1
# kingdom : 1
# 1 : 1
# billion : 1
# company : 1
# founded : 1

# %%
pos = nltk.pos_tag(lemmatized)

print(pos)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipykernel_1705/927497035.py in <cell line: 0>()
# ----> 1 pos = nltk.pos_tag(lemmatized)
#       2
#       3 print(pos)
#
# /usr/local/lib/python3.12/dist-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     166     :rtype: list(tuple(str, str))
#     167     """
# --> 168     tagger = _get_tagger(lang)
#     169     return _pos_tag(tokens, tagset, tagger, lang)
#     170
#
# /usr/local/lib/python3.12/dist-packages/nltk/tag/__init__.py in _get_tagger(lang)
#     108         tagger = PerceptronTagger(lang=lang)
#     109     else:
# --> 110         tagger = PerceptronTagger()
#     111     return tagger
#     112
#
# /usr/local/lib/python3.12/dist-packages/nltk/tag/perceptron.py in __init__(self, load, lang)
#     181         self.classes = set()
#     182         if load:
# ...

# %%
nlp = spacy.load("en_core_web_sm")

doc = nlp(text)

for entity in doc.ents:
    print(entity.text, "---->", entity.label_)
# Out:
# Apple ----> ORG
# the United Kingdom ----> GPE
# $1 billion ----> MONEY
# John ----> PERSON
# 2019 ----> DATE
