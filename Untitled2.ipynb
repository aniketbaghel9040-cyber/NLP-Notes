# %% [markdown]
# <a href="https://colab.research.google.com/github/aniketbaghel9040-cyber/NLP-Notes/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello NLP")
print("Python is working successfully!")
# Out:
# Hello NLP
# Python is working successfully!

# %%
# !pip install scikit-learn gensim
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement gensimimport (from versions: none)
# ERROR: No matching distribution found for gensimimport

# %%
import nltk

print("NLTK version:", nltk.__version__)
# Out:
# NLTK version: 3.9.1

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
text = """
Natural Language Processing is a branch of Artificial Intelligence.
It helps computers understand human language.
NLP is used in chatbots, Google Search, translation and sentiment analysis.
"""

print(text)
# Out:
# Natural Language Processing is a branch of Artificial Intelligence.
# It helps computers understand human language.
# NLP is used in chatbots, Google Search, translation and sentiment analysis.

# %%
from nltk.tokenize import sent_tokenize

sentences = sent_tokenize(text)

print("Total sentences:", len(sentences))

for i, sentence in enumerate(sentences, 1):
    print(i, ":", sentence)
# Out:
# Total sentences: 3
# 1 :
# Natural Language Processing is a branch of Artificial Intelligence.
# 2 : It helps computers understand human language.
# 3 : NLP is used in chatbots, Google Search, translation and sentiment analysis.

# %%
from nltk.tokenize import word_tokenize

tokens = word_tokenize(text)

print("Total tokens:", len(tokens))
print(tokens)
# Out:
# Total tokens: 31
# ['Natural', 'Language', 'Processing', 'is', 'a', 'branch', 'of', 'Artificial', 'Intelligence', '.', 'It', 'helps', 'computers', 'understand', 'human', 'language', '.', 'NLP', 'is', 'used', 'in', 'chatbots', ',', 'Google', 'Search', ',', 'translation', 'and', 'sentiment', 'analysis', '.']

# %%
lower_text = text.lower()

print(lower_text)
# Out:
# natural language processing is a branch of artificial intelligence.
# it helps computers understand human language.
# nlp is used in chatbots, google search, translation and sentiment analysis.

# %%
lower_tokens = [word.lower() for word in tokens]

print(lower_tokens)
# Out:
# ['natural', 'language', 'processing', 'is', 'a', 'branch', 'of', 'artificial', 'intelligence', '.', 'it', 'helps', 'computers', 'understand', 'human', 'language', '.', 'nlp', 'is', 'used', 'in', 'chatbots', ',', 'google', 'search', ',', 'translation', 'and', 'sentiment', 'analysis', '.']

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

print("Number of stop words:", len(stop_words))
print(list(stop_words)[:20])
# Out:
# Number of stop words: 198
# ['at', 'about', 'by', 'm', 'it', 'she', 'won', 'there', 'a', "weren't", "you'd", 'between', 'his', 'is', 'my', 'to', 'yourselves', 'ain', 'can', 'where']

# %%
filtered_words = []

for word in tokens:
    if word.lower() not in stop_words:
            filtered_words.append(word)

            print("Original Tokens:")
            print(tokens)

            print("\nAfter Stop Word Removal:")
            print(filtered_words)
# Out:
# Original Tokens:
# ['Natural', 'Language', 'Processing', 'is', 'a', 'branch', 'of', 'Artificial', 'Intelligence', '.', 'It', 'helps', 'computers', 'understand', 'human', 'language', '.', 'NLP', 'is', 'used', 'in', 'chatbots', ',', 'Google', 'Search', ',', 'translation', 'and', 'sentiment', 'analysis', '.']
#
# After Stop Word Removal:
# ['Natural']
# Original Tokens:
# ['Natural', 'Language', 'Processing', 'is', 'a', 'branch', 'of', 'Artificial', 'Intelligence', '.', 'It', 'helps', 'computers', 'understand', 'human', 'language', '.', 'NLP', 'is', 'used', 'in', 'chatbots', ',', 'Google', 'Search', ',', 'translation', 'and', 'sentiment', 'analysis', '.']
#
# After Stop Word Removal:
# ['Natural', 'Language']
# Original Tokens:
# ...

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

words = [
    "play",
        "playing",
            "played",
                "plays",
                    "study",
                        "studying",
                            "studies"
                            ]

                            for word in words:
                                print(word, "->", stemmer.stem(word))
# Out:
#   File "/tmp/ipykernel_2875/2113897423.py", line 15
#     for word in words:
#     ^
# IndentationError: unexpected indent

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

words = [
    "play",
    "playing",
     "played",
    "plays",
    "study",
    "studying",
    "studies" ]
for word in words:
  print(word, "->", stemmer.stem(word))
# Out:
# play -> play
# playing -> play
# played -> play
# plays -> play
# study -> studi
# studying -> studi
# studies -> studi

# %%
for word in words:
      print(word, "->", stemmer.stem(word))
# Out:
# play -> play
# playing -> play
# played -> play
# plays -> play
# study -> studi
# studying -> studi
# studies -> studi
